# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation/blob/architecture/function5.ipynb
# )

# %%
import os
import sys


current_dir = os.getcwd()
repo_root = current_dir

while "scripts" not in os.listdir(repo_root):
    parent = os.path.abspath(os.path.join(repo_root, ".."))
    if parent == repo_root:  # reached filesystem root
        raise FileNotFoundError("Cannot find 'scripts' folder in parent directories")
    repo_root = parent

# Add repo root to Python path
if repo_root not in sys.path:
    sys.path.append(repo_root)

print("Added repo root to sys.path:", repo_root)

import scripts
# import scripts.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build
import scripts.BBOloop as bbo_loop
# Out:
# Added repo root to sys.path: /workspaces/MLProject_CapstoneBlackBoxOptimisation

# %%
# SETUP FOR COLAB TO LOAD SCRIPTS
# ===============================

# --- GitHub URL ---
GITHUB_URL = "https://github.com/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation.git"
BRANCH = "architecture"
REPO_PATH = "/content/mydear"

# Clonrepo if not already cloned
import os
import numpy as np

if not os.path.exists(REPO_PATH):
    # !git clone -b {BRANCH} {GITHUB_URL} {REPO_PATH}


# --- Option 2: Google Drive ---
# from google.colab import drive
# drive.mount('/content/drive')
# Change path below if using Drive
# repo_path = '/content/drive/MyDrive/yourrepo'

# -----------------------------
# Install scripts folder as package
# e ensures any edits to scripts are reflected immediately

# -----------------------------
# !pip uninstall -y scripts
# !pip install -e {REPO_PATH}/scripts/

import sys
sys.path.append(REPO_PATH)
import sys, os

sys.path.append(os.path.join(REPO_PATH, "scripts"))
sys.path.append(os.path.join(REPO_PATH, "scripts/utils"))

# If you update utils.py while Colab is running, you can force a reload:

# import importlib
# import scripts.utils
# importlib.reload(scripts.utils)

# Add the scripts folder to sys.path
scripts_path = os.path.abspath("../scripts")  # relative path from notebook to scripts
sys.path.append(scripts_path)
import sys
sys.path.append(f"{REPO_PATH}/scripts")

# from scripts.setup.gpBuilder import build_gp, build_svr, build_kernel_from_config

import scripts
import scripts.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build


import scripts.BBOloop as bbo_loop  # if you saved the BBO loop in a script

# %%
# imports 

import scripts
import scripts.configs.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build


import scripts.BBOloop as bbo_loop

# %%
# refresh

import importlib
import scripts.utils
importlib.reload(scripts)
# Out:
# <module 'scripts' from '/workspaces/MLProject_CapstoneBlackBoxOptimisation/scripts/__init__.py'>

# %%
functionNo = 2
# weekNo = 6
weekNo = 8

# %%
# install 
# !pip install numpy scipy scikit-learn matplotlib joblib lightgbm

# %%
from scripts.utils.weekly_data import get_weekly_inputs, get_weekly_outputs
import numpy as np
inputs = get_weekly_inputs(functionNo=functionNo,weekNo = weekNo)
outputs = get_weekly_outputs(functionNo=functionNo,weekNo = weekNo)
print(len(outputs))
X_train = np.array(inputs)
y_train = np.array(outputs)
# print(X_train.shape)
# print(y_train.shape)
print(X_train)
print(y_train)
# Out:
# Initial count: 10
# Weekly count: 8
# Combined: 18
# 18
# [[0.66579958 0.12396913]
#  [0.87779099 0.7786275 ]
#  [0.14269907 0.34900513]
#  [0.84527543 0.71112027]
#  [0.45464714 0.29045518]
#  [0.57771284 0.77197318]
#  [0.43816606 0.68501826]
#  [0.34174959 0.02869772]
#  [0.33864816 0.21386725]
#  [0.70263656 0.9265642 ]
#  [0.566581   0.045364  ]
#  [0.723782   0.206887  ]
#  [0.702637   0.926564  ]
#  [0.010819   0.996021  ]
#  [0.999067   0.028224  ]
#  [0.702637   0.926564  ]
#  [0.702637   0.926564  ]
#  [0.691693   0.080155  ]]
# [ 0.53899612  0.42058624 -0.06562362  0.29399291  0.21496451  0.02310555
#   0.24461934  0.03874902 -0.01385762  0.61120522 -0.00528752  0.45667614
#   0.68408532  0.01271428 -0.04623472  0.59364521  0.58942184  0.73343852]

# %%
for func_name, results in all_results.items():
    # Find overall best from iteration results
    best_iter_info = max(results, key=lambda r: r["best_output"])
    
    best_input = best_iter_info["best_input"]
    best_output = best_iter_info["best_output"]
    kernel = best_iter_info["kernel"]
    kernel_params = best_iter_info["kernel_params"]
    acquisition = best_iter_info["acquisition"]

    print(f"Function: {func_name}")
    print(f"  Best method: {acquisition}")
    print(f"  Kernel: {kernel}")
    print(f"  Kernel parameters: {kernel_params}")
    print(f"  Best y: {best_output:.6f}")
    print("  Best x: " + " - ".join(f"{x:.6f}" for x in best_input))
    print("-" * 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for func_name, results in all_results.items():
#       2     # Find overall best from iteration results
#       3     best_iter_info = max(results, key=lambda r: r["best_output"])
#       5     best_input = best_iter_info["best_input"]
#
# NameError: name 'all_results' is not defined

# %%
from scripts.BBOloop import *
config = funcConfig.FUNCTION_CONFIG[functionNo]
best_x, best_y, history = bbo_loop_ForceInwards( X_train, y_train, config)
print("Best input found (batch):", best_x)
print("Best output (batch):", best_y)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 1000000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 1000000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 1: Optimized kernel = 0.96**2 * Matern(length_scale=[0.145, 1e+06], nu=0.5) + WhiteKernel(noise_level=0.0209)
# ...

# %%
from scripts.utils.generate_colab_button import *

GITHUB_USER = "AnnemarieKeller"
REPO_NAME = "MLProject_CapstoneBlackBoxOptimisation"
BRANCH_NAME = "architecture"

ROOT_DIR = "."  # or path to the folder containing your notebooks

add_badge_to_all_notebooks(ROOT_DIR, GITHUB_USER, REPO_NAME, BRANCH_NAME)
print("Finished adding Colab badges to notebooks.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from scripts.utils.generate_colab_button import *
#       3 GITHUB_USER = "AnnemarieKeller"
#       4 REPO_NAME = "MLProject_CapstoneBlackBoxOptimisation"
#
# ModuleNotFoundError: No module named 'scripts'

# %%
print(X_train.shape[1])

config = funcConfig.FUNCTION_CONFIG[functionNo]
print("Kernel type selected:", config.get("kernel_type"))
best_inputwithWHite, best_outputwithWhite, historyWithWhite= (bbo_loopWith(X_train, y_train, config, "EI"))
print("best_input" , best_inputwithWHite)
print( "-".join(f"{x:.6f}" for x in best_inputwithWHite))
print("best_output" , best_outputwithWhite)
# print(historyWithWhite, "history")
#  0.6840853188300118 - week 5 matern
# Out:
# 2
# Kernel type selected: Matern
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 1000000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 1000000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 1: Optimized kernel = 0.96**2 * Matern(length_scale=[0.145, 1e+06], nu=0.5) + WhiteKernel(noise_level=0.0209)
# Iter 2: Optimized kernel = 0.989**2 * Matern(length_scale=[0.175, 1.56e+05], nu=0.5) + WhiteKernel(noise_level=0.0177)
# ...

# %%
importlib.reload(scripts.BBOloop)
from scripts.BBOloop import *
config = funcConfig.FUNCTION_CONFIG[functionNo]
best_inputwithdynamic, best_outputwithdynamic, historyDynamic= function_free_bbo_dynamic(
    X_init=X_train,
    y_init=y_train,
    function_config=config, 
    num_iterations=30
)
print("best_input" , best_inputwithdynamic)
print("best_output" , best_outputwithdynamic)
print( "-".join(f"{x:.6f}" for x in best_inputwithdynamic))
# print(historyDynamic, "history")

# %%
from scripts.BBOloop import *
config = funcConfig.FUNCTION_CONFIG[functionNo]
best_gp_x, best_gp_y, history_gp = function_free_bbo_multi_acq(X_train, y_train, config =config,num_iterations=60)
best_svr_x, best_svr_y , history_svr= svr_bbo_loop(X_train, y_train, config)
best_dynamic, bestdymaicy_, dymnicas_history= adaptive_bbo_dynamic(X_train, y_train, config)

print("GP best input:", best_gp_x, "value:", best_gp_y)
print( "-".join(f"{x:.6f}" for x in best_gp_x))
print("SVR best input:", best_svr_x, "value:", best_svr_y)
print( "-".join(f"{x:.6f}" for x in best_svr_x))
print("Dymnaic best input:", best_dynamic, "value:",bestdymaicy_)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
best_x, best_y, history =BO_committee_single(X_train, y_train, 4)
print("Best input found:", best_x)
print("Best output:", best_y)
# Out:
# Skipping fold for gp due to error: Anisotropic kernel must have the same number of dimensions as data (4!=2)
# Skipping fold for gp due to error: Anisotropic kernel must have the same number of dimensions as data (4!=2)
# Skipping fold for gp due to error: Anisotropic kernel must have the same number of dimensions as data (4!=2)
# [LightGBM] [Warning] There are no meaningful features which satisfy the provided configuration. Decreasing Dataset parameters min_data_in_bin or min_data_in_leaf and re-constructing Dataset might resolve this warning.
# [LightGBM] [Info] Total Bins 0
# [LightGBM] [Info] Number of data points in the train set: 12, number of used features: 0
# [LightGBM] [Info] Start training from score 0.337472
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# ...
