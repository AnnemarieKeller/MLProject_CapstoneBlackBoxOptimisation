# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation/blob/architecture/dfunction2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SETUP FOR COLAB TO LOAD SCRIPTS
# ===============================

# --- GitHub URL ---
GITHUB_URL = "https://github.com/AnnemarieKeller/MLProject_CapstoneBlackBoxOptimisation.git"
BRANCH = "architecture"
REPO_PATH = "/content/mydear"

# Clonrepo if not already cloned
import os
import numpy as np

if not os.path.exists(REPO_PATH):
    # !git clone -b {BRANCH} {GITHUB_URL} {REPO_PATH}


# --- Option 2: Google Drive ---
# from google.colab import drive
# drive.mount('/content/drive')
# Change path below if using Drive
# repo_path = '/content/drive/MyDrive/yourrepo'

# -----------------------------
# Install scripts folder as package
# e ensures any edits to scripts are reflected immediately

# -----------------------------
# !pip uninstall -y scripts
# !pip install -e {REPO_PATH}/scripts/

import sys
sys.path.append(REPO_PATH)
import sys, os

sys.path.append(os.path.join(REPO_PATH, "scripts"))
sys.path.append(os.path.join(REPO_PATH, "scripts/utils"))

# If you update utils.py while Colab is running, you can force a reload:

# import importlib
# import scripts.utils
# importlib.reload(scripts.utils)

# Add the scripts folder to sys.path
scripts_path = os.path.abspath("../scripts")  # relative path from notebook to scripts
sys.path.append(scripts_path)
import sys
sys.path.append(f"{REPO_PATH}/scripts")

# from scripts.setup.gpBuilder import build_gp, build_svr, build_kernel_from_config

import scripts
import scripts.configs.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build


import scripts.BBOloop as bbo_loop
# Out:
# fatal: could not create leading directories of '/content/mydear': Permission denied
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 52
#      48 sys.path.append(f"{REPO_PATH}/scripts")
#      50 # from scripts.setup.gpBuilder import build_gp, build_svr, build_kernel_from_config
# ---> 52 import scripts
#      53 import scripts.functionConfig as funcConfig
#      54 import scripts.accquistions as acq
#
# ModuleNotFoundError: No module named 'scripts'

# %%
best_x, best_y, history =BO_committee_single(X_train, y_train, 8)
print("Best input found:", best_x)
print("Best output:", best_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_x, best_y, history =BO_committee_single(X_train, y_train, 8)
#       2 print("Best input found:", best_x)
#       3 print("Best output:", best_y)
#
# NameError: name 'BO_committee_single' is not defined

# %%
# !pip install numpy scipy scikit-learn matplotlib joblib pyDOE2

# %%
# !pip install lightgbm

# %%
import os
import sys


current_dir = os.getcwd()
repo_root = current_dir

while "scripts" not in os.listdir(repo_root):
    parent = os.path.abspath(os.path.join(repo_root, ".."))
    if parent == repo_root:  # reached filesystem root
        raise FileNotFoundError("Cannot find 'scripts' folder in parent directories")
    repo_root = parent

# Add repo root to Python path
if repo_root not in sys.path:
    sys.path.append(repo_root)

print("Added repo root to sys.path:", repo_root)

import scripts
import scripts.configs.functionConfig as funcConfig
import scripts.accquistions as acq
import scripts.setBoundary as bound
import scripts.setup.gpBuilder as build
import scripts.BBOloop as bbo_loop
# Out:
# Added repo root to sys.path: /workspaces/MLProject_CapstoneBlackBoxOptimisation

# %%
from scripts.utils.read_inputs_outputs import *
from scripts.BBOloop import *

from collections import defaultdict
from scripts.week8strat import *

weekno = 7
results = defaultdict(dict)
X_train, y_train = generate_data(1, weekno)
print("function1 x and y data")
print(X_train)
print(y_train)
print("------------------------")

X_train, y_train = generate_data(5, weekno)
print("function5 x and y data")
print(X_train)
print(y_train)
print("------------------------")
X_train, y_train = generate_data(8, weekno)
print("function8 x and y data")
print(X_train)
print(y_train)
# Out:
# Initial count: 10
# Weekly count: 7
# Combined: 17
# 17
# function1 x and y data
# [[0.31940389 0.76295937]
#  [0.57432921 0.8798981 ]
#  [0.73102363 0.73299988]
#  [0.84035342 0.26473161]
#  [0.65011406 0.68152635]
#  [0.41043714 0.1475543 ]
#  [0.31269116 0.07872278]
#  [0.68341817 0.86105746]
#  [0.08250725 0.40348751]
#  [0.88388983 0.58225397]
#  [0.202514   0.586723  ]
#  [0.489595   0.116877  ]
#  [0.020026   0.996624  ]
#  [0.956717   0.004359  ]
#  [0.985825   0.98681   ]
#  [0.044772   0.931757  ]
#  [0.951495   0.745322  ]]
# [ 1.32267704e-079  1.03307824e-046  7.71087511e-016  3.34177101e-124
#  -3.60606264e-003 -2.15924904e-054 -2.08909327e-091  2.53500115e-040
#   3.60677119e-081  6.22985647e-048 -3.82874120e-053 -1.73341564e-068
#   0.00000000e+000  5.02464762e-321  7.54496238e-180 -1.94082680e-282
#  -8.61999215e-084]
# ------------------------
# Initial count: 20
# Weekly count: 7
# Combined: 27
# 27
# function5 x and y data
# [[0.19144708 0.03819337 0.60741781 0.41458414]
#  [0.75865295 0.53651774 0.65600038 0.36034155]
#  [0.43834987 0.8043397  0.21024527 0.15129482]
#  [0.70605083 0.53419196 0.26424335 0.48208755]
#  [0.83647799 0.19360965 0.6638927  0.78564888]
#  [0.68343225 0.11866264 0.82904591 0.56757661]
#  [0.55362148 0.66734998 0.32380582 0.81486975]
#  [0.35235627 0.32224153 0.11697937 0.47311252]
#  [0.15378571 0.72938169 0.42259844 0.44307417]
#  [0.46344227 0.63002451 0.10790646 0.9576439 ]
#  [0.67749115 0.35850951 0.47959222 0.07288048]
#  [0.58397341 0.14724265 0.34809746 0.42861465]
#  [0.30688872 0.31687813 0.62263448 0.09539906]
#  [0.51114177 0.817957   0.72871042 0.11235362]
#  [0.43893338 0.77409176 0.37816709 0.93369621]
#  [0.22418902 0.84648049 0.87948418 0.87851568]
#  [0.72526172 0.47987049 0.08894684 0.75976022]
#  [0.35548161 0.63961937 0.41761768 0.12260384]
#  [0.11987923 0.86254031 0.64333133 0.84980383]
#  [0.12688467 0.15342962 0.77016219 0.19051811]
#  [0.37454    0.950714   0.731994   0.598658  ]
#  [0.608145   0.136893   0.454197   0.808606  ]
#  [0.224189   0.84648    0.879484   0.878516  ]
#  [0.258008   0.925806   0.879484   0.957644  ]
#  [0.274937   0.803879   0.952871   0.996928  ]
#  [0.701628   0.298494   0.517804   0.511965  ]
#  [0.071846   0.99024    0.96578    0.979771  ]]
# [6.44434399e+01 1.83013796e+01 1.12939795e-01 4.21089813e+00
#  2.58370525e+02 7.84343889e+01 5.75715369e+01 1.09571876e+02
#  8.84799176e+00 2.33223610e+02 2.44230883e+01 6.44201468e+01
#  6.34767158e+01 7.97291299e+01 3.55806818e+02 1.08885962e+03
#  2.88667516e+01 4.51815703e+01 4.31612757e+02 9.97233189e+00
#  4.37294278e+02 1.47952193e+01 1.08885819e+03 2.04706853e+03
#  2.18106841e+03 4.02714013e+00 3.62495741e+03]
# ------------------------
# Initial count: 40
# Weekly count: 7
# Combined: 47
# 47
# function8 x and y data
# [[0.60499445 0.29221502 0.90845275 0.35550624 0.20166872 0.57533801
#   0.31031095 0.73428138]
#  [0.17800696 0.56622265 0.99486184 0.21032501 0.32015266 0.70790879
#   0.63538449 0.10713163]
#  [0.00907698 0.81162615 0.52052036 0.07568668 0.26511183 0.09165169
#   0.59241515 0.36732026]
#  [0.50602816 0.65373012 0.36341078 0.17798105 0.0937283  0.19742533
#   0.7558269  0.29247234]
#  [0.35990926 0.24907568 0.49599717 0.70921498 0.11498719 0.28920692
#   0.55729515 0.59388173]
#  [0.77881834 0.0034195  0.33798313 0.51952778 0.82090699 0.53724669
#   0.5513471  0.66003209]
#  [0.90864932 0.0622497  0.23825955 0.76660355 0.13233596 0.99024381
#   0.68806782 0.74249594]
#  [0.58637144 0.88073573 0.74502075 0.54603485 0.00964888 0.74899176
#   0.23090707 0.09791562]
#  [0.76113733 0.85467239 0.38212433 0.33735198 0.68970832 0.30985305
#   0.63137968 0.04195607]
#  [0.9849332  0.69950626 0.9988855  0.18014846 0.58014315 0.23108719
#   0.49082694 0.31368272]
#  [0.11207131 0.43773566 0.59659878 0.59277563 0.22698177 0.41010452
#   0.92123758 0.67475276]
#  [0.79188751 0.57619134 0.69452836 0.28342378 0.13675546 0.27916186
#   0.84276726 0.62532792]
#  [0.1435503  0.93741452 0.23232482 0.00904349 0.41457893 0.40932517
#   0.55377852 0.2058408 ]
#  [0.76991655 0.45875909 0.55900044 0.69460444 0.50319902 0.72834638
#   0.78425353 0.66313109]
#  [0.05644741 0.06595555 0.02292868 0.03878647 0.40393544 0.80105533
#   0.48830701 0.89308498]
#  [0.86243745 0.48273382 0.2818694  0.54410223 0.88749026 0.38265469
#   0.60190199 0.47646169]
#  [0.3515119  0.59006494 0.9094363  0.67840835 0.21282566 0.08846038
#   0.410153   0.19572429]
#  [0.73590364 0.03461189 0.72803027 0.14742652 0.29574314 0.44511731
#   0.97517969 0.37433978]
#  [0.68029397 0.25510465 0.86218799 0.13439582 0.3263292  0.28790687
#   0.43501048 0.36420013]
#  [0.04432925 0.01358149 0.25819824 0.57764416 0.05127992 0.15856307
#   0.59103012 0.07795293]
#  [0.77834548 0.75114565 0.31414221 0.90298577 0.33538166 0.38632267
#   0.74897249 0.9887551 ]
#  [0.89888711 0.5236417  0.87678325 0.21869645 0.90026089 0.28276624
#   0.91107791 0.47239822]
#  [0.14512029 0.11932754 0.42088822 0.38760861 0.15542283 0.87517163
#   0.51055967 0.72861058]
#  [0.33895442 0.56693202 0.3767511  0.09891573 0.65945169 0.24554809
#   0.76248278 0.73215347]
#  [0.17615002 0.29396143 0.97567997 0.79393631 0.92340076 0.03084229
#   0.80325452 0.59589758]
#  [0.02894663 0.02827906 0.48137155 0.6131746  0.67266045 0.02211341
#   0.6014833  0.52488505]
#  [0.19263987 0.63067728 0.41679584 0.49052929 0.79608602 0.65456706
#   0.27624119 0.29551759]
#  [0.94318502 0.21885062 0.72118408 0.42459707 0.986902   0.53518298
#   0.71474318 0.96009372]
#  [0.5327214  0.8336926  0.071399   0.11681148 0.73069311 0.93737559
#   0.86650798 0.127902  ]
#  [0.44709584 0.84395253 0.72954612 0.63915138 0.40928714 0.13264569
#   0.03590888 0.44683847]
#  [0.38222497 0.55713584 0.85310163 0.33379569 0.26572127 0.48087292
#   0.23764706 0.76863196]
#  [0.53281953 0.86230848 0.53826712 0.04944293 0.71970119 0.9067059
#   0.10823094 0.52534791]
#  [0.39486519 0.33180167 0.7407543  0.69786172 0.73740444 0.78377681
#   0.25449546 0.87114551]
#  [0.98594539 0.87305363 0.07039262 0.05358729 0.73415296 0.52025852
#   0.81104004 0.10336036]
#  [0.96457339 0.97397979 0.66375335 0.66221599 0.67312167 0.90523762
#   0.45887462 0.5609175 ]
#  [0.47207071 0.16820264 0.08642757 0.45265551 0.48061922 0.62243949
#   0.92897446 0.11253627]
#  [0.85600695 0.6388937  0.32619202 0.66850311 0.24029837 0.21029889
#   0.16754636 0.96358986]
#  [0.81003174 0.63504604 0.26954758 0.86960534 0.66192159 0.25225873
#   0.76567003 0.89054867]
#  [0.79625252 0.00703653 0.35569738 0.48756605 0.74051962 0.7066501
#   0.99291449 0.38173437]
#  [0.48124533 0.10246072 0.21948594 0.67732237 0.24750919 0.24434086
#   0.16382453 0.71596164]
#  [0.056447   0.065956   0.022929   0.038786   0.403935   0.801055
#   0.488307   0.893085  ]
#  [0.121691   0.771271   0.03259    0.825315   0.045019   0.960567
#   0.194183   0.941319  ]
#  [0.119997   0.027034   0.268042   0.182266   0.646048   0.361599
#   0.189501   0.526882  ]
#  [0.151419   0.139627   0.104801   0.144751   0.854834   0.51486
#   0.167028   0.492837  ]
#  [0.110366   0.24412    0.309408   0.147372   0.900342   0.686379
#   0.048773   0.630922  ]
#  [0.151419   0.139627   0.104801   0.144751   0.854834   0.51486
#   0.167028   0.492837  ]
#  [0.210757   0.086417   0.047402   0.203606   0.996764   0.395799
#   0.195777   0.399168  ]]
# [7.3987211  7.00522736 8.45948162 8.28400781 8.60611679 8.54174792
#  7.32743458 7.29987205 7.95787474 5.59219339 7.85454099 6.79198578
#  8.97655402 7.3790829  9.598482   8.15998319 7.13162397 6.76796253
#  7.43374407 9.01307515 7.31089382 5.84106731 9.14163949 8.81755844
#  6.45194313 8.83074505 9.34427428 6.88784639 8.04221254 7.69236805
#  7.92375877 8.42175924 8.2780624  7.11345716 6.40258841 8.47293632
#  7.97768459 7.46087219 7.43659353 9.18300525 9.59848214 8.61972721
#  9.8941112  9.98762515 9.8087517  9.98762515 9.91379718]

# %%
import importlib
import scripts.utils
importlib.reload(scripts)

# %%
functionNo = 8
weekNo = 3

# %%
from scripts.utils.read_inputs_outputs import *
import numpy as np
X_train, y_train = generate_data(functionNo, weekNo)
print(X_train.shape)
print(y_train.shape)
print(X_train)
print(y_train)
# Out:
# Initial count: 40
# Weekly count: 3
# Combined: 43
# 43
# (43, 8)
# (43,)
# [[0.60499445 0.29221502 0.90845275 0.35550624 0.20166872 0.57533801
#   0.31031095 0.73428138]
#  [0.17800696 0.56622265 0.99486184 0.21032501 0.32015266 0.70790879
#   0.63538449 0.10713163]
#  [0.00907698 0.81162615 0.52052036 0.07568668 0.26511183 0.09165169
#   0.59241515 0.36732026]
#  [0.50602816 0.65373012 0.36341078 0.17798105 0.0937283  0.19742533
#   0.7558269  0.29247234]
#  [0.35990926 0.24907568 0.49599717 0.70921498 0.11498719 0.28920692
#   0.55729515 0.59388173]
#  [0.77881834 0.0034195  0.33798313 0.51952778 0.82090699 0.53724669
#   0.5513471  0.66003209]
#  [0.90864932 0.0622497  0.23825955 0.76660355 0.13233596 0.99024381
#   0.68806782 0.74249594]
#  [0.58637144 0.88073573 0.74502075 0.54603485 0.00964888 0.74899176
#   0.23090707 0.09791562]
#  [0.76113733 0.85467239 0.38212433 0.33735198 0.68970832 0.30985305
#   0.63137968 0.04195607]
#  [0.9849332  0.69950626 0.9988855  0.18014846 0.58014315 0.23108719
#   0.49082694 0.31368272]
#  [0.11207131 0.43773566 0.59659878 0.59277563 0.22698177 0.41010452
#   0.92123758 0.67475276]
#  [0.79188751 0.57619134 0.69452836 0.28342378 0.13675546 0.27916186
#   0.84276726 0.62532792]
#  [0.1435503  0.93741452 0.23232482 0.00904349 0.41457893 0.40932517
#   0.55377852 0.2058408 ]
#  [0.76991655 0.45875909 0.55900044 0.69460444 0.50319902 0.72834638
#   0.78425353 0.66313109]
#  [0.05644741 0.06595555 0.02292868 0.03878647 0.40393544 0.80105533
#   0.48830701 0.89308498]
#  [0.86243745 0.48273382 0.2818694  0.54410223 0.88749026 0.38265469
#   0.60190199 0.47646169]
#  [0.3515119  0.59006494 0.9094363  0.67840835 0.21282566 0.08846038
#   0.410153   0.19572429]
#  [0.73590364 0.03461189 0.72803027 0.14742652 0.29574314 0.44511731
#   0.97517969 0.37433978]
#  [0.68029397 0.25510465 0.86218799 0.13439582 0.3263292  0.28790687
#   0.43501048 0.36420013]
#  [0.04432925 0.01358149 0.25819824 0.57764416 0.05127992 0.15856307
#   0.59103012 0.07795293]
#  [0.77834548 0.75114565 0.31414221 0.90298577 0.33538166 0.38632267
#   0.74897249 0.9887551 ]
#  [0.89888711 0.5236417  0.87678325 0.21869645 0.90026089 0.28276624
#   0.91107791 0.47239822]
#  [0.14512029 0.11932754 0.42088822 0.38760861 0.15542283 0.87517163
#   0.51055967 0.72861058]
#  [0.33895442 0.56693202 0.3767511  0.09891573 0.65945169 0.24554809
#   0.76248278 0.73215347]
#  [0.17615002 0.29396143 0.97567997 0.79393631 0.92340076 0.03084229
#   0.80325452 0.59589758]
#  [0.02894663 0.02827906 0.48137155 0.6131746  0.67266045 0.02211341
#   0.6014833  0.52488505]
#  [0.19263987 0.63067728 0.41679584 0.49052929 0.79608602 0.65456706
#   0.27624119 0.29551759]
#  [0.94318502 0.21885062 0.72118408 0.42459707 0.986902   0.53518298
#   0.71474318 0.96009372]
#  [0.5327214  0.8336926  0.071399   0.11681148 0.73069311 0.93737559
#   0.86650798 0.127902  ]
#  [0.44709584 0.84395253 0.72954612 0.63915138 0.40928714 0.13264569
#   0.03590888 0.44683847]
#  [0.38222497 0.55713584 0.85310163 0.33379569 0.26572127 0.48087292
#   0.23764706 0.76863196]
#  [0.53281953 0.86230848 0.53826712 0.04944293 0.71970119 0.9067059
#   0.10823094 0.52534791]
#  [0.39486519 0.33180167 0.7407543  0.69786172 0.73740444 0.78377681
#   0.25449546 0.87114551]
#  [0.98594539 0.87305363 0.07039262 0.05358729 0.73415296 0.52025852
#   0.81104004 0.10336036]
#  [0.96457339 0.97397979 0.66375335 0.66221599 0.67312167 0.90523762
#   0.45887462 0.5609175 ]
#  [0.47207071 0.16820264 0.08642757 0.45265551 0.48061922 0.62243949
#   0.92897446 0.11253627]
#  [0.85600695 0.6388937  0.32619202 0.66850311 0.24029837 0.21029889
#   0.16754636 0.96358986]
#  [0.81003174 0.63504604 0.26954758 0.86960534 0.66192159 0.25225873
#   0.76567003 0.89054867]
#  [0.79625252 0.00703653 0.35569738 0.48756605 0.74051962 0.7066501
#   0.99291449 0.38173437]
#  [0.48124533 0.10246072 0.21948594 0.67732237 0.24750919 0.24434086
#   0.16382453 0.71596164]
#  [0.056447   0.065956   0.022929   0.038786   0.403935   0.801055
#   0.488307   0.893085  ]
#  [0.121691   0.771271   0.03259    0.825315   0.045019   0.960567
#   0.194183   0.941319  ]
#  [0.119997   0.027034   0.268042   0.182266   0.646048   0.361599
#   0.189501   0.526882  ]]
# [7.3987211  7.00522736 8.45948162 8.28400781 8.60611679 8.54174792
#  7.32743458 7.29987205 7.95787474 5.59219339 7.85454099 6.79198578
#  8.97655402 7.3790829  9.598482   8.15998319 7.13162397 6.76796253
#  7.43374407 9.01307515 7.31089382 5.84106731 9.14163949 8.81755844
#  6.45194313 8.83074505 9.34427428 6.88784639 8.04221254 7.69236805
#  7.92375877 8.42175924 8.2780624  7.11345716 6.40258841 8.47293632
#  7.97768459 7.46087219 7.43659353 9.18300525 9.59848214 8.61972721
#  9.8941112 ]

# %%
batch_size = 5  # evaluate 5 points per iteration
n_jobs = -1     # use all CPU cores
from scripts.BBOloop import *
dim = X_train.shape[1]
best_x, best_y, history =bayes_opt_rf_batch(
    X_init=X_train,
    y_init=y_train,  
    input_dim=dim,
    n_iterations=50,
    n_candidates=2000,
    batch_size=batch_size,
    acquisition_methods=["UCB", "EI", "PI"],
 
    use_boundary=True,
    boost_middle=True,
    n_jobs=n_jobs
)

print("Best input found (batch):", best_x)
print("Best output (batch):", best_y)
# Out:
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# candidate generated
# Best input found (batch): [0.10714124 0.03259282 0.10039984 0.13861596 0.55769095 0.69995524
#  0.19591768 0.38575187]
# Best output (batch): 9.492122629167856

# %%
config = funcConfig.FUNCTION_CONFIG[functionNo]
best_x, best_y, history = bbo_loop_ForceInwards( X_train, y_train, config)
print("Best input found (batch):", best_x)
print("Best output (batch):", best_y)
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.293058728994563. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.293058728994563. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.293058728994563. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.293058728994563. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 1: Optimized kernel = Matern(length_scale=[1.2, 1.73, 0.83, 2.23, 4.1, 11.3, 1.25, 11.3], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.197521632266076. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.197521632266076. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.197521632266076. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.197521632266076. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 2: Optimized kernel = Matern(length_scale=[1.2, 1.74, 0.836, 2.22, 4.12, 11.2, 1.26, 11.2], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.113209690962602. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.113209690962602. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.113209690962602. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.113209690962602. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 3: Optimized kernel = Matern(length_scale=[1.24, 1.77, 0.855, 2.27, 4.23, 11.1, 1.3, 11.1], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.058913651799173. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.058913651799173. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 11.058913651799173. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 11.058913651799173. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 25 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Iter 4: Optimized kernel = Matern(length_scale=[1.26, 1.82, 0.873, 2.33, 4.33, 11.1, 1.33, 11.1], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.987760143508147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.987760143508147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 25 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.987760143508147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.987760143508147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 5: Optimized kernel = Matern(length_scale=[1.29, 1.85, 0.895, 2.39, 4.46, 11, 1.36, 11], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.980955862978714. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.980955862978714. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.980955862978714. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.980955862978714. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 6: Optimized kernel = Matern(length_scale=[1.3, 1.87, 0.904, 2.46, 4.6, 11, 1.37, 11], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 33 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.871682969480855. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.871682969480855. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 33 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.871682969480855. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.871682969480855. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 7: Optimized kernel = Matern(length_scale=[1.33, 1.88, 0.912, 2.5, 4.65, 10.9, 1.39, 10.9], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.836063587738971. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.836063587738971. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.836063587738971. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.836063587738971. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 8: Optimized kernel = Matern(length_scale=[1.35, 1.89, 0.922, 2.55, 4.67, 10.8, 1.41, 10.8], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.816441388295672. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.816441388295672. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.816441388295672. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.816441388295672. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 9: Optimized kernel = Matern(length_scale=[1.37, 1.91, 0.929, 2.58, 4.8, 10.8, 1.44, 10.8], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.801356784435292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.801356784435292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.801356784435292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.801356784435292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 10: Optimized kernel = Matern(length_scale=[1.4, 1.94, 0.944, 2.6, 4.99, 10.8, 1.47, 10.8], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.776545330477576. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.776545330477576. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.776545330477576. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.776545330477576. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 11: Optimized kernel = Matern(length_scale=[1.41, 1.96, 0.964, 2.65, 5.06, 10.8, 1.49, 10.8], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.782445644357292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.782445644357292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.782445644357292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.782445644357292. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 12: Optimized kernel = Matern(length_scale=[1.43, 1.97, 0.966, 2.73, 5.09, 10.8, 1.49, 10.8], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.679382299364544. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.679382299364544. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.679382299364544. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.679382299364544. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 13: Optimized kernel = Matern(length_scale=[1.44, 1.97, 0.969, 2.76, 5.08, 10.7, 1.51, 10.7], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.602115805938798. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.602115805938798. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.602115805938798. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.602115805938798. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 14: Optimized kernel = Matern(length_scale=[1.45, 1.97, 0.971, 2.75, 5.08, 10.6, 1.52, 10.6], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.614197375922792. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.614197375922792. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.614197375922792. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.614197375922792. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 19 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Iter 15: Optimized kernel = Matern(length_scale=[1.47, 1.99, 0.982, 2.78, 5.14, 10.6, 1.54, 10.6], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.567837404612739. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.567837404612739. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/_gpr.py:663: ConvergenceWarning: lbfgs failed to converge after 19 iteration(s) (status=2):
# ABNORMAL:
#
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.567837404612739. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.567837404612739. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 16: Optimized kernel = Matern(length_scale=[1.48, 2.02, 0.989, 2.8, 5.18, 10.6, 1.55, 10.6], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.553007085338162. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.553007085338162. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.553007085338162. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.553007085338162. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 17: Optimized kernel = Matern(length_scale=[1.5, 2.04, 0.997, 2.82, 5.29, 10.6, 1.57, 10.6], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.50329522678136. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.50329522678136. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.50329522678136. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.50329522678136. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 18: Optimized kernel = Matern(length_scale=[1.51, 2.06, 1.01, 2.84, 5.39, 10.5, 1.59, 10.5], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.489610826760094. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.489610826760094. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.489610826760094. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.489610826760094. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 19: Optimized kernel = Matern(length_scale=[1.52, 2.09, 1.02, 2.88, 5.49, 10.5, 1.6, 10.5], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.439494950953026. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.439494950953026. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.439494950953026. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.439494950953026. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 20: Optimized kernel = Matern(length_scale=[1.54, 2.1, 1.03, 2.93, 5.52, 10.4, 1.61, 10.4], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.437877955506316. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.437877955506316. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.437877955506316. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.437877955506316. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 21: Optimized kernel = Matern(length_scale=[1.55, 2.11, 1.03, 2.95, 5.56, 10.4, 1.63, 10.4], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.39346725727816. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.39346725727816. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.39346725727816. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.39346725727816. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 22: Optimized kernel = Matern(length_scale=[1.57, 2.15, 1.04, 2.97, 5.66, 10.4, 1.65, 10.4], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.392220115146651. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.392220115146651. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.392220115146651. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 23: Optimized kernel = Matern(length_scale=[1.58, 2.17, 1.06, 3.01, 5.77, 10.4, 1.66, 10.4], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.331309426546621. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.331309426546621. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.331309426546621. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.331309426546621. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 24: Optimized kernel = Matern(length_scale=[1.6, 2.19, 1.06, 3.02, 5.82, 10.3, 1.68, 10.3], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.334533634159078. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.334533634159078. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.334533634159078. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.334533634159078. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 25: Optimized kernel = Matern(length_scale=[1.61, 2.2, 1.07, 3.04, 5.97, 10.3, 1.7, 10.3], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.263599989780229. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.263599989780229. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.263599989780229. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.263599989780229. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 26: Optimized kernel = Matern(length_scale=[1.61, 2.2, 1.08, 3.04, 5.99, 10.3, 1.7, 10.3], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.25209585810147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.25209585810147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.25209585810147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.25209585810147. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 27: Optimized kernel = Matern(length_scale=[1.62, 2.22, 1.08, 3.06, 6.19, 10.3, 1.71, 10.3], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.24278460705889. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.24278460705889. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.24278460705889. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.24278460705889. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 28: Optimized kernel = Matern(length_scale=[1.63, 2.23, 1.09, 3.08, 6.37, 10.2, 1.71, 10.2], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.176621958625802. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.176621958625802. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.176621958625802. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.176621958625802. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 29: Optimized kernel = Matern(length_scale=[1.63, 2.24, 1.09, 3.09, 6.37, 10.2, 1.72, 10.2], nu=2.5) + WhiteKernel(noise_level=1e-08)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.141257786858489. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.141257786858489. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# Iter 30: Optimized kernel = Matern(length_scale=[1.64, 2.24, 1.1, 3.1, 6.36, 10.1, 1.72, 10.1], nu=2.5) + WhiteKernel(noise_level=1e-08)
# Best input found (batch): [0.30800714 0.12253585 0.15898461 0.05139664 0.82157602 0.4070919
#  0.10810563 0.23275424]
# Best output (batch): 10.007480070423448
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 5 of parameter k1__length_scale is close to the specified upper bound 10.141257786858489. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:450: ConvergenceWarning: The optimal value found for dimension 7 of parameter k1__length_scale is close to the specified upper bound 10.141257786858489. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/gaussian_process/kernels.py:440: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
config = funcConfig.FUNCTION_CONFIG[functionNo]
dim = config.get("dim")
n_init = 10
X_init = X_train
y_init = y_train
# Run BO
best_x, best_y, history = BOLoop_rf(
    X_init=X_init,
    y_init=y_init,
    input_dim=dim,
    n_iterations=50,
    n_candidates=1000,
    acquisition_methods=["UCB", "EI", "PI"],
    # use_boundary=True,
    boost_middle=True
)

print("Best input found:", best_x)
print("Best output:", best_y)
# Out:
# Iter 1: New predicted input, predicted_y=8.607572
# Iter 2: New predicted input, predicted_y=7.808156
# Iter 3: New predicted input, predicted_y=8.429052
# Iter 4: New predicted input, predicted_y=7.904316
# Iter 5: New predicted input, predicted_y=8.133455
# Iter 6: New predicted input, predicted_y=7.461002
# Iter 7: New predicted input, predicted_y=8.751061
# Iter 8: New predicted input, predicted_y=8.378802
# Iter 9: New predicted input, predicted_y=8.616496
# Iter 10: New predicted input, predicted_y=8.713923
# Iter 11: New predicted input, predicted_y=8.013444
# Iter 12: New predicted input, predicted_y=8.759006
# Iter 13: New predicted input, predicted_y=9.011930
# Iter 14: New predicted input, predicted_y=9.143366
# Iter 15: New predicted input, predicted_y=7.441013
# Iter 16: New predicted input, predicted_y=8.687328
# Iter 17: New predicted input, predicted_y=8.852351
# Iter 18: New predicted input, predicted_y=8.062573
# Iter 19: New predicted input, predicted_y=9.193671
# Iter 20: New predicted input, predicted_y=7.994573
# Iter 21: New predicted input, predicted_y=8.619569
# Iter 22: New predicted input, predicted_y=9.166223
# Iter 23: New predicted input, predicted_y=9.187597
# Iter 24: New predicted input, predicted_y=8.065134
# Iter 25: New predicted input, predicted_y=8.789842
# Iter 26: New predicted input, predicted_y=9.402929
# Iter 27: New predicted input, predicted_y=8.389037
# Iter 28: New predicted input, predicted_y=7.759980
# Iter 29: New predicted input, predicted_y=9.279880
# Iter 30: New predicted input, predicted_y=8.695315
# Iter 31: New predicted input, predicted_y=9.298316
# Iter 32: New predicted input, predicted_y=9.446761
# Iter 33: New predicted input, predicted_y=9.294951
# Iter 34: New predicted input, predicted_y=8.676063
# Iter 35: New predicted input, predicted_y=9.270100
# Iter 36: New predicted input, predicted_y=9.340694
# Iter 37: New predicted input, predicted_y=8.149825
# Iter 38: New predicted input, predicted_y=9.383138
# Iter 39: New predicted input, predicted_y=7.855987
# Iter 40: New predicted input, predicted_y=9.394664
# Iter 41: New predicted input, predicted_y=9.464070
# Iter 42: New predicted input, predicted_y=8.651676
# Iter 43: New predicted input, predicted_y=7.772908
# Iter 44: New predicted input, predicted_y=8.633539
# Iter 45: New predicted input, predicted_y=9.291089
# Iter 46: New predicted input, predicted_y=8.710370
# Iter 47: New predicted input, predicted_y=8.650096
# Iter 48: New predicted input, predicted_y=8.643158
# Iter 49: New predicted input, predicted_y=9.350002
# Iter 50: New predicted input, predicted_y=8.251277
# Best input found: [0.52405174 0.32380606 0.42446436 0.64544704 0.40285041 0.3974118
#  0.36288961 0.44366234]
# Best output: 8.251277458793462

# %%
import numpy as np
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler



# Standardize inputs (helps SVR)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# SVR ensemble for pseudo-uncertainty
n_ensembles = 5
svr_ensemble = [SVR(kernel='rbf', C=10.0, epsilon=0.01) for _ in range(n_ensembles)]

# Fit ensemble
for model in svr_ensemble:
    model.fit(X_train_scaled, y_train)

input_dim = X_train.shape[1]
num_iterations = 30
num_candidates = 1000

for i in range(num_iterations):
    # Generate random candidates
    candidates = np.random.rand(num_candidates, input_dim)
    candidates_scaled = scaler.transform(candidates)

    # Predict with ensemble
    preds = np.array([m.predict(candidates_scaled) for m in svr_ensemble])
    mean_pred = preds.mean(axis=0)
    std_pred = preds.std(axis=0)

    # Upper Confidence Bound acquisition
    beta = 2.0  # exploration/exploitation trade-off
    ucb = mean_pred + beta * std_pred

    # Pick next candidate
    idx_next = np.argmax(ucb)
    next_input = candidates[idx_next]
    next_output = np.sin(np.sum(next_input))  # Replace with your real function

    print(f"Iter {i+1}: Next input = {next_input}, Predicted output = {mean_pred[idx_next]:.4f}, UCB = {ucb[idx_next]:.4f}, Real output = {next_output:.4f}")

    # Add new observation to training set
    X_train = np.vstack([X_train, next_input])
    y_train = np.append(y_train, next_output)
    X_train_scaled = scaler.fit_transform(X_train)

    # Refit ensemble
    svr_ensemble = [SVR(kernel='rbf', C=10.0, epsilon=0.01) for _ in range(n_ensembles)]
    for model in svr_ensemble:
        model.fit(X_train_scaled, y_train)

# After loop, find best observed
best_idx = np.argmax(y_train)
print("\nBest input found:", X_train[best_idx])
print("Best output observed:", y_train[best_idx])

# %%
from scripts.BBOloop import *
import importlib


print(X_train.shape[1])

config = funcConfig.FUNCTION_CONFIG[functionNo]
print("Kernel type selected:", config.get("kernel_type"))
best_inputwithWHite, best_outputwithWhite, historyWithWhite= (bbo_loopWith(X_train, y_train, config, "EI"))
print("best_input" , best_inputwithWHite)
print( "-".join(f"{x:.6f}" for x in best_inputwithWHite))
print("best_output" , best_outputwithWhite)
# print(historyWithWhite, "history")
#  0.6840853188300118 - week 5 matern
# best_input [0.702637 0.926564]
# best_outuput 0.6840853188300118

# %%
import matplotlib.pyplot as plt
import numpy as np

X = X_train
y = y_train

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

for i in range(4):
    ax = axes[i//2, i%2]
    ax.scatter(X[:, i], y, c=y, cmap='viridis')
    ax.set_title(f"Input dim {i+1} vs Output")
    ax.set_xlabel(f"x{i+1}")
    ax.set_ylabel("Output")
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
import importlib
import scripts.configs.functionConfig as funcConfig
importlib.reload(funcConfig)

# %%
import importlib
import scripts.BBOloop as BBOloop

importlib.reload(BBOloop)

# %%
print( "-".join(f"{x:.6f}" for x in best_inputwithWHite))

# %%
importlib.reload(scripts.BBOloop)
from scripts.BBOloop import *
config = funcConfig.FUNCTION_CONFIG[functionNo]
best_inputwithdynamic, best_outputwithdynamic, historyDynamic= function_free_bbo_dynamic(
    X_init=X_train,
    y_init=y_train,
    function_config=config, 
    num_iterations=30
)
print("best_input" , best_inputwithdynamic)
print("best_output" , best_outputwithdynamic)
print( "-".join(f"{x:.6f}" for x in best_inputwithdynamic))
# print(historyDynamic, "history")

# %%
# config = funcConfig.FUNCTION_CONFIG[functionNo]
best_gp_x, best_gp_y, history_gp = function_free_bbo_multi_acq(X_train, y_train, config =config,num_iterations=60)
best_svr_x, best_svr_y , history_svr= svr_bbo_loop(X_train, y_train, config)
best_dynamic, bestdymaicy_, dymnicas_history= adaptive_bbo_dynamic(X_train, y_train, config)

print("GP best input:", best_gp_x, "value:", best_gp_y)
print("SVR best input:", best_svr_x, "value:", best_svr_y)
print("Dymnaic best input:", best_dynamic, "value:",bestdymaicy_)

# %%
best_dynamic, bestdymaicy_, dymnicas_history= adaptive_bbo_dynamic(X_train, y_train, config = config)

# %%
print("GP best input:", best_gp_x, "value:", best_gp_y)
print("SVR best input:", best_svr_x, "value:", best_svr_y)

# %%
max_value = max(best_outputwithWhite, best_outputwithdynamic)
print(max_value)
# best_input [0.0049505 0.9994626]
# best_output 0.9356618643138697
# 0.004951-0.999463
# best_input [0.57771284 0.77197318]
# best_output 0.9828830808596889
# 0.577713-0.771973
# best_input [0.70263656 0.9265642 ]
# best_output 0.990976744531639
# 0.702637-0.926564

# %%
from scripts import BBOloop
import importlib
import scripts.BBOloop
importlib.reload(scripts.BBOloop)
from scripts.BBOloop import function_free_bbo_dynamic
# List all attributes in BBOloop
dir(BBOloop)
